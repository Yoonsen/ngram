# %%
import dhlab_v2 as d2

# %%
def konk(corpus = None, query = None): 
    conc = d2.concordance(urns = list(corpus.urn), words = query, limit = 10000)
    conc['link'] = conc['urn'].apply(lambda c: "<a target='_blank' href = 'https://www.nb.no/items/{x}?searchText={q}'>{display}</a>".format(x = c, display = c.split('_')[2], q = query))
    conc['date'] = conc['urn'].apply(lambda c: "{display}".format( display = c.split('_')[-1][:4]))
    return conc[['link','date','conc']].sort_values(by = 'date')

# %%
doctype = "digitidsskrift"
title_ft = None
subject_ft = None
ddk_ft = None
period_slider = (1970, 1990)
allword = "helse"

# %%
samples = d2.document_corpus(doctype = doctype, title = title_ft, subject = subject_ft, ddk = ddk_ft, from_year = period_slider[0], to_year = period_slider[1], limit = 2000)

# st.write(samples[:10])

#print('\n\n'.join([' '.join(("https://urn.nb.no/" + r[1][0], r[1][1])) for r in d2.concordance(urns = samples, words =" ".join(allword))[['urn','conc']][:60].iterrows()]).replace('<b>','**').replace('</b>', '**'))

conc = konk(corpus = samples, query = allword)

# %%
# !pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.8.9

# %%
conc.sample(min(200, len(conc))).to_markdown()
# Out:
# '|      | link                                                                                                                                  |   date | conc                                                                                                                                                                                                                                                        |\n|-----:|:--------------------------------------------------------------------------------------------------------------------------------------|-------:|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| 2621 | <a target=\'_blank\' href = \'https://www.nb.no/items/URN:NBN:no-nb_digitidsskrift_2017113081100_001?searchText=helse\'>2017113081100</a> |    001 | ... Gaver A / s Sandaker Apotek Sandaker Foto A / s Sandaker fritidsklubb Sandaker <b>helse</b>- og sosialsenter Sandaker helsestasjon Sandaker postkontor Sandaker Senterforening A / s Soria-Sandaker...                                                  |\n| 1562 | <a target=\'_blank\' href = \'https://www.nb.no/items/URN:NBN:no-nb_digitidsskrift_2019101481101_001?searchText=helse\'>2019101481101</a> |    001 | ... Hans <b>helse</b> er dårlig , og han har ikke annen inntekt enn uføretrygden . Under disse omstendigheter finner jeg ikke grunnlag for å forhøye den idømte bot...                                                                                      |\n| 1149 | <a target=\'_blank\' href = \'https://www.nb.no/items/URN:NBN:no-nb_digitidsskrift_2021010783357_001?searchText=helse\'>2021010783357</a> |    001 | Lån til <b>helse</b>- og sosialbygg                                                                                                                                                                                                                         |\n| 2566 | <a target=\'_blank\' href = \'https://www.nb.no/items/URN:NBN:no-nb_digitidsskrift_2018102581535_001?searchText=helse\'>2018102581535</a> |    001 | SP tar opp rusgiftpolitikken under to avsnitt : " Barn og ungdom " under hovedkapittelet " Mennesket i miljøet " og " Alkohol og stoffmisbruk " under kapittelet " <b>Helse</b>- og sosialpolitikk " .                                                      |\n| 2921 | <a target=\'_blank\' href = \'https://www.nb.no/items/URN:NBN:no-nb_digitidsskrift_2019061781056_001?searchText=helse\'>2019061781056</a> |    001 | ... Et mål — en mening — for egen <b>helse</b> .                                                                                                                                                                                                            |\n| 3065 | <a target=\'_blank\' href = \'https://www.nb.no/items/URN:NBN:no-nb_digitidsskrift_2019022881171_001?searchText=helse\'>2019022881171</a> |    001 | ... Kr 124 , - Ame Maltén Kari Killén Heap I ÆRFRROLLFN FORSØMTE FAMILIER En utfordring til <b>helse</b>- og Ved Egil Viken . Kr 138 , sosialarbeidere . Kr 58 , - Persson...                                                                               |\n|  152 | <a target=\'_blank\' href = \'https://www.nb.no/items/URN:NBN:no-nb_digitidsskrift_2021020381020_001?searchText=helse\'>2021020381020</a> |    001 | ... situasjon med god funksjonsevne , og vel halvparten hadde fått bedret sin psykiske <b>helse</b> i løpet av observasjonstiden . Et verdifullt arbeid er også Vaglums ( 5 ) . Han...                                                                      |\n| 2673 | <a target=\'_blank\' href = \'https://www.nb.no/items/URN:NBN:no-nb_digitidsskrift_2019012381233_001?searchText=helse\'>2019012381233</a> |    001 | ... Barn og unge vedkommer alle etatene i kommunen både <b>helse</b> og sosialetaten , skoleetaten , kulturetaten og teknisk etat .  ...
